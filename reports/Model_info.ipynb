# %%
setwd("G:\\My Drive\\SDM_China\\")
library("rstan")
# Out:
# Loading required package: StanHeaders
#
# Loading required package: ggplot2
#
# rstan (Version 2.19.2, GitRev: 2e1f913d3ca3)
#
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
#
# For improved execution time, we recommend calling
# Sys.setenv(LOCAL_CPPFLAGS = '-march=native')
# although this causes Stan to throw an error on a few processors.

# %%
mname<-'parabolic_simple_iCAR_new'
stan_model<-paste('stan_models/',mname,'.stan',sep="")
path2model<-paste('outputs/models/',mname,'.rds',sep="")

# %%
fit<-readRDS(path2model)

# %%
fit@stan_args
# Out:
# [[1]]
# [[1]]$chain_id
# [1] 1
#
# [[1]]$iter
# [1] 10000
#
# [[1]]$thin
# [1] 1
#
# [[1]]$seed
# [1] 1930389121
#
# [[1]]$warmup
# [1] 2000
#
# [[1]]$init
# [1] "random"
#
# [[1]]$algorithm
# [1] "NUTS"
#
# [[1]]$check_unknown_args
# [1] FALSE
#
# [[1]]$method
# [1] "sampling"
#
#
# [[2]]
# [[2]]$chain_id
# [1] 2
#
# [[2]]$iter
# [1] 10000
#
# [[2]]$thin
# [1] 1
#
# [[2]]$seed
# [1] 1930389121
#
# [[2]]$warmup
# [1] 2000
#
# [[2]]$init
# [1] "random"
#
# [[2]]$algorithm
# [1] "NUTS"
#
# [[2]]$check_unknown_args
# [1] FALSE
#
# [[2]]$method
# [1] "sampling"
#
#
# [[3]]
# [[3]]$chain_id
# [1] 3
#
# [[3]]$iter
# [1] 10000
#
# [[3]]$thin
# [1] 1
#
# [[3]]$seed
# [1] 1930389121
#
# [[3]]$warmup
# [1] 2000
#
# [[3]]$init
# [1] "random"
#
# [[3]]$algorithm
# [1] "NUTS"
#
# [[3]]$check_unknown_args
# [1] FALSE
#
# [[3]]$method
# [1] "sampling"
#
#
# [[4]]
# [[4]]$chain_id
# [1] 4
#
# [[4]]$iter
# [1] 10000
#
# [[4]]$thin
# [1] 1
#
# [[4]]$seed
# [1] 1930389121
#
# [[4]]$warmup
# [1] 2000
#
# ...

# %% [markdown]
# ###
#
# The simple iCAR model has 50000 iteration, over 5 chains (100000 iterations per chain, using 20000 iterations as warmups)
# Predictions for the check contain 40 000 samples from the posterior for each country.
# Posterior predictions contain.
# The counterfactual predictions are based on 1000 data points, and 40 000 predicitons for each point.
